# %% [markdown]
# # Neural Networks
#
# In this notebook, we will look at neural networks for image classification

# %%
import torch
from torch import nn
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torchinfo import summary

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
BATCH_SIZE = 32

# %%
trainsforms = transforms.Compose([
    transforms.ToTensor()
])

# %%
train_dataset = torchvision.datasets.CIFAR10(train = True, root = './data', download = True, transform = transforms.ToTensor())
train_loader = DataLoader(train_dataset, batch_size = BATCH_SIZE, shuffle = True)
test_dataset = torchvision.datasets.CIFAR10(train = False, root = './data', download = True, transform = transforms.ToTensor())
test_loader = DataLoader(test_dataset, batch_size = BATCH_SIZE, shuffle = False)
print(len(train_dataset), len(test_dataset))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 50000 10000

# %%
model = torchvision.models.googlenet(weights = torchvision.models.GoogLeNet_Weights.DEFAULT)

# %%
model.fc = nn.Linear(1024, 10)
print(model)
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception3b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception4a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(208, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(16, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(224, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4c): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(24, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4d): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(112, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(144, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(288, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception4e): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception5a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (inception5b): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch3): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(48, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=True)
#       (1): BasicConv2d(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (aux1): None
#   (aux2): None
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1024, out_features=10, bias=True)
# )

# %%
model = model.to(device)

# %%
random_tensor = torch.rand(10, 3, 32, 32).to(device)
print(summary(model = model, input_data=random_tensor, verbose=2, col_names=['input_size', 'output_size', 'num_params', 'trainable']))
# Out:
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Trainable
# ============================================================================================================================================
# GoogLeNet                                [10, 3, 32, 32]           [10, 10]                  --                        True
# ├─BasicConv2d: 1-1                       [10, 3, 32, 32]           [10, 64, 16, 16]          --                        True
# │    └─conv.weight                                                                           ├─9,408
# │    └─bn.weight                                                                             ├─64
# │    └─bn.bias                                                                               └─64
# │    └─Conv2d: 2-1                       [10, 3, 32, 32]           [10, 64, 16, 16]          9,408                     True
# │    │    └─weight                                                                           └─9,408
# │    └─BatchNorm2d: 2-2                  [10, 64, 16, 16]          [10, 64, 16, 16]          128                       True
# │    │    └─weight                                                                           ├─64
# │    │    └─bias                                                                             └─64
# ├─MaxPool2d: 1-2                         [10, 64, 16, 16]          [10, 64, 8, 8]            --                        --
# ├─BasicConv2d: 1-3                       [10, 64, 8, 8]            [10, 64, 8, 8]            --                        True
# │    └─conv.weight                                                                           ├─4,096
# │    └─bn.weight                                                                             ├─64
# │    └─bn.bias                                                                               └─64
# │    └─Conv2d: 2-3                       [10, 64, 8, 8]            [10, 64, 8, 8]            4,096                     True
# │    │    └─weight                                                                           └─4,096
# │    └─BatchNorm2d: 2-4                  [10, 64, 8, 8]            [10, 64, 8, 8]            128                       True
# │    │    └─weight                                                                           ├─64
# │    │    └─bias                                                                             └─64
# ├─BasicConv2d: 1-4                       [10, 64, 8, 8]            [10, 192, 8, 8]           --                        True
# │    └─conv.weight                                                                           ├─110,592
# │    └─bn.weight                                                                             ├─192
# │    └─bn.bias                                                                               └─192
# │    └─Conv2d: 2-5                       [10, 64, 8, 8]            [10, 192, 8, 8]           110,592                   True
# │    │    └─weight                                                                           └─110,592
# │    └─BatchNorm2d: 2-6                  [10, 192, 8, 8]           [10, 192, 8, 8]           384                       True
# │    │    └─weight                                                                           ├─192
# │    │    └─bias                                                                             └─192
# ├─MaxPool2d: 1-5                         [10, 192, 8, 8]           [10, 192, 4, 4]           --                        --
# ├─Inception: 1-6                         [10, 192, 4, 4]           [10, 256, 4, 4]           --                        True
# │    └─branch1.conv.weight                                                                   ├─12,288
# │    └─branch1.bn.weight                                                                     ├─64
# │    └─branch1.bn.bias                                                                       ├─64
# │    └─branch2.0.conv.weight                                                                 ├─18,432
# │    └─branch2.0.bn.weight                                                                   ├─96
# │    └─branch2.0.bn.bias                                                                     ├─96
# │    └─branch2.1.conv.weight                                                                 ├─110,592
# │    └─branch2.1.bn.weight                                                                   ├─128
# │    └─branch2.1.bn.bias                                                                     ├─128
# │    └─branch3.0.conv.weight                                                                 ├─3,072
# │    └─branch3.0.bn.weight                                                                   ├─16
# │    └─branch3.0.bn.bias                                                                     ├─16
# │    └─branch3.1.conv.weight                                                                 ├─4,608
# │    └─branch3.1.bn.weight                                                                   ├─32
# │    └─branch3.1.bn.bias                                                                     ├─32
# │    └─branch4.1.conv.weight                                                                 ├─6,144
# │    └─branch4.1.bn.weight                                                                   ├─32
# │    └─branch4.1.bn.bias                                                                     └─32
# │    └─BasicConv2d: 2-7                  [10, 192, 4, 4]           [10, 64, 4, 4]            --                        True
# │    │    └─conv.weight                                                                      ├─12,288
# │    │    └─bn.weight                                                                        ├─64
# │    │    └─bn.bias                                                                          └─64
# │    │    └─Conv2d: 3-1                  [10, 192, 4, 4]           [10, 64, 4, 4]            12,288                    True
# │    │    │    └─weight                                                                      └─12,288
# │    │    └─BatchNorm2d: 3-2             [10, 64, 4, 4]            [10, 64, 4, 4]            128                       True
# │    │    │    └─weight                                                                      ├─64
# │    │    │    └─bias                                                                        └─64
# │    └─Sequential: 2-8                   [10, 192, 4, 4]           [10, 128, 4, 4]           --                        True
# │    │    └─0.conv.weight                                                                    ├─18,432
# │    │    └─0.bn.weight                                                                      ├─96
# │    │    └─0.bn.bias                                                                        ├─96
# │    │    └─1.conv.weight                                                                    ├─110,592
# │    │    └─1.bn.weight                                                                      ├─128
# │    │    └─1.bn.bias                                                                        └─128
# │    │    └─BasicConv2d: 3-3             [10, 192, 4, 4]           [10, 96, 4, 4]            18,624                    True
# │    │    │    └─conv.weight                                                                 ├─18,432
# │    │    │    └─bn.weight                                                                   ├─96
# │    │    │    └─bn.bias                                                                     └─96
# │    │    └─BasicConv2d: 3-4             [10, 96, 4, 4]            [10, 128, 4, 4]           110,848                   True
# │    │    │    └─conv.weight                                                                 ├─110,592
# │    │    │    └─bn.weight                                                                   ├─128
# │    │    │    └─bn.bias                                                                     └─128
# │    └─Sequential: 2-9                   [10, 192, 4, 4]           [10, 32, 4, 4]            --                        True
# │    │    └─0.conv.weight                                                                    ├─3,072
# │    │    └─0.bn.weight                                                                      ├─16
# │    │    └─0.bn.bias                                                                        ├─16
# │    │    └─1.conv.weight                                                                    ├─4,608
# │    │    └─1.bn.weight                                                                      ├─32
# │    │    └─1.bn.bias                                                                        └─32
# │    │    └─BasicConv2d: 3-5             [10, 192, 4, 4]           [10, 16, 4, 4]            3,104                     True
# │    │    │    └─conv.weight                                                                 ├─3,072
# │    │    │    └─bn.weight                                                                   ├─16
# │    │    │    └─bn.bias                                                                     └─16
# │    │    └─BasicConv2d: 3-6             [10, 16, 4, 4]            [10, 32, 4, 4]            4,672                     True
# │    │    │    └─conv.weight                                                                 ├─4,608
# │    │    │    └─bn.weight                                                                   ├─32
# │    │    │    └─bn.bias                                                                     └─32
# │    └─Sequential: 2-10                  [10, 192, 4, 4]           [10, 32, 4, 4]            --                        True
# │    │    └─1.conv.weight                                                                    ├─6,144
# │    │    └─1.bn.weight                                                                      ├─32
# │    │    └─1.bn.bias                                                                        └─32
# │    │    └─MaxPool2d: 3-7               [10, 192, 4, 4]           [10, 192, 4, 4]           --                        --
# │    │    └─BasicConv2d: 3-8             [10, 192, 4, 4]           [10, 32, 4, 4]            6,208                     True
# │    │    │    └─conv.weight                                                                 ├─6,144
# │    │    │    └─bn.weight                                                                   ├─32
# │    │    │    └─bn.bias                                                                     └─32
# ├─Inception: 1-7                         [10, 256, 4, 4]           [10, 480, 4, 4]           --                        True
# │    └─branch1.conv.weight                                                                   ├─32,768
# │    └─branch1.bn.weight                                                                     ├─128
# │    └─branch1.bn.bias                                                                       ├─128
# │    └─branch2.0.conv.weight                                                                 ├─32,768
# │    └─branch2.0.bn.weight                                                                   ├─128
# │    └─branch2.0.bn.bias                                                                     ├─128
# │    └─branch2.1.conv.weight                                                                 ├─221,184
# │    └─branch2.1.bn.weight                                                                   ├─192
# │    └─branch2.1.bn.bias                                                                     ├─192
# │    └─branch3.0.conv.weight                                                                 ├─8,192
# │    └─branch3.0.bn.weight                                                                   ├─32
# │    └─branch3.0.bn.bias                                                                     ├─32
# │    └─branch3.1.conv.weight                                                                 ├─27,648
# │    └─branch3.1.bn.weight                                                                   ├─96
# │    └─branch3.1.bn.bias                                                                     ├─96
# │    └─branch4.1.conv.weight                                                                 ├─16,384
# │    └─branch4.1.bn.weight                                                                   ├─64
# │    └─branch4.1.bn.bias                                                                     └─64
# │    └─BasicConv2d: 2-11                 [10, 256, 4, 4]           [10, 128, 4, 4]           --                        True
# │    │    └─conv.weight                                                                      ├─32,768
# │    │    └─bn.weight                                                                        ├─128
# │    │    └─bn.bias                                                                          └─128
# │    │    └─Conv2d: 3-9                  [10, 256, 4, 4]           [10, 128, 4, 4]           32,768                    True
# │    │    │    └─weight                                                                      └─32,768
# │    │    └─BatchNorm2d: 3-10            [10, 128, 4, 4]           [10, 128, 4, 4]           256                       True
# │    │    │    └─weight                                                                      ├─128
# │    │    │    └─bias                                                                        └─128
# │    └─Sequential: 2-12                  [10, 256, 4, 4]           [10, 192, 4, 4]           --                        True
# │    │    └─0.conv.weight                                                                    ├─32,768
# │    │    └─0.bn.weight                                                                      ├─128
# │    │    └─0.bn.bias                                                                        ├─128
# │    │    └─1.conv.weight                                                                    ├─221,184
# │    │    └─1.bn.weight                                                                      ├─192
# │    │    └─1.bn.bias                                                                        └─192
# │    │    └─BasicConv2d: 3-11            [10, 256, 4, 4]           [10, 128, 4, 4]           33,024                    True
# │    │    │    └─conv.weight                                                                 ├─32,768
# │    │    │    └─bn.weight                                                                   ├─128
# │    │    │    └─bn.bias                                                                     └─128
# │    │    └─BasicConv2d: 3-12            [10, 128, 4, 4]           [10, 192, 4, 4]           221,568                   True
# │    │    │    └─conv.weight                                                                 ├─221,184
# │    │    │    └─bn.weight                                                                   ├─192
# │    │    │    └─bn.bias                                                                     └─192
# │    └─Sequential: 2-13                  [10, 256, 4, 4]           [10, 96, 4, 4]            --                        True
# │    │    └─0.conv.weight                                                                    ├─8,192
# │    │    └─0.bn.weight                                                                      ├─32
# │    │    └─0.bn.bias                                                                        ├─32
# │    │    └─1.conv.weight                                                                    ├─27,648
# │    │    └─1.bn.weight                                                                      ├─96
# │    │    └─1.bn.bias                                                                        └─96
# │    │    └─BasicConv2d: 3-13            [10, 256, 4, 4]           [10, 32, 4, 4]            8,256                     True
# │    │    │    └─conv.weight                                                                 ├─8,192
# │    │    │    └─bn.weight                                                                   ├─32
# │    │    │    └─bn.bias                                                                     └─32
# │    │    └─BasicConv2d: 3-14            [10, 32, 4, 4]            [10, 96, 4, 4]            27,840                    True
# │    │    │    └─conv.weight                                                                 ├─27,648
# │    │    │    └─bn.weight                                                                   ├─96
# │    │    │    └─bn.bias                                                                     └─96
# │    └─Sequential: 2-14                  [10, 256, 4, 4]           [10, 64, 4, 4]            --                        True
# │    │    └─1.conv.weight                                                                    ├─16,384
# │    │    └─1.bn.weight                                                                      ├─64
# │    │    └─1.bn.bias                                                                        └─64
# │    │    └─MaxPool2d: 3-15              [10, 256, 4, 4]           [10, 256, 4, 4]           --                        --
# │    │    └─BasicConv2d: 3-16            [10, 256, 4, 4]           [10, 64, 4, 4]            16,512                    True
# │    │    │    └─conv.weight                                                                 ├─16,384
# │    │    │    └─bn.weight                                                                   ├─64
# │    │    │    └─bn.bias                                                                     └─64
# ├─MaxPool2d: 1-8                         [10, 480, 4, 4]           [10, 480, 2, 2]           --                        --
# ├─Inception: 1-9                         [10, 480, 2, 2]           [10, 512, 2, 2]           --                        True
# │    └─branch1.conv.weight                                                                   ├─92,160
# │    └─branch1.bn.weight                                                                     ├─192
# │    └─branch1.bn.bias                                                                       ├─192
# │    └─branch2.0.conv.weight                                                                 ├─46,080
# │    └─branch2.0.bn.weight                                                                   ├─96
# │    └─branch2.0.bn.bias                                                                     ├─96
# │    └─branch2.1.conv.weight                                                                 ├─179,712
# │    └─branch2.1.bn.weight                                                                   ├─208
# │    └─branch2.1.bn.bias                                                                     ├─208
# │    └─branch3.0.conv.weight                                                                 ├─7,680
# │    └─branch3.0.bn.weight                                                                   ├─16
# │    └─branch3.0.bn.bias                                                                     ├─16
# │    └─branch3.1.conv.weight                                                                 ├─6,912
# │    └─branch3.1.bn.weight                                                                   ├─48
# │    └─branch3.1.bn.bias                                                                     ├─48
# │    └─branch4.1.conv.weight                                                                 ├─30,720
# │    └─branch4.1.bn.weight                                                                   ├─64
# │    └─branch4.1.bn.bias                                                                     └─64
# │    └─BasicConv2d: 2-15                 [10, 480, 2, 2]           [10, 192, 2, 2]           --                        True
# │    │    └─conv.weight                                                                      ├─92,160
# │    │    └─bn.weight                                                                        ├─192
# │    │    └─bn.bias                                                                          └─192
# │    │    └─Conv2d: 3-17                 [10, 480, 2, 2]           [10, 192, 2, 2]           92,160                    True
# │    │    │    └─weight                                                                      └─92,160
# │    │    └─BatchNorm2d: 3-18            [10, 192, 2, 2]           [10, 192, 2, 2]           384                       True
# │    │    │    └─weight                                                                      ├─192
# │    │    │    └─bias                                                                        └─192
# │    └─Sequential: 2-16                  [10, 480, 2, 2]           [10, 208, 2, 2]           --                        True
# │    │    └─0.conv.weight                                                                    ├─46,080
# │    │    └─0.bn.weight                                                                      ├─96
# │    │    └─0.bn.bias                                                                        ├─96
# │    │    └─1.conv.weight                                                                    ├─179,712
# │    │    └─1.bn.weight                                                                      ├─208
# │    │    └─1.bn.bias                                                                        └─208
# │    │    └─BasicConv2d: 3-19            [10, 480, 2, 2]           [10, 96, 2, 2]            46,272                    True
# │    │    │    └─conv.weight                                                                 ├─46,080
# │    │    │    └─bn.weight                                                                   ├─96
# │    │    │    └─bn.bias                                                                     └─96
# │    │    └─BasicConv2d: 3-20            [10, 96, 2, 2]            [10, 208, 2, 2]           180,128                   True
# │    │    │    └─conv.weight                                                                 ├─179,712
# │    │    │    └─bn.weight                                                                   ├─208
# │    │    │    └─bn.bias                                                                     └─208
# │    └─Sequential: 2-17                  [10, 480, 2, 2]           [10, 48, 2, 2]            --                        True
# │    │    └─0.conv.weight                                                                    ├─7,680
# │    │    └─0.bn.weight                                                                      ├─16
# │    │    └─0.bn.bias                                                                        ├─16
# │    │    └─1.conv.weight                                                                    ├─6,912
# │    │    └─1.bn.weight                                                                      ├─48
# │    │    └─1.bn.bias                                                                        └─48
# │    │    └─BasicConv2d: 3-21            [10, 480, 2, 2]           [10, 16, 2, 2]            7,712                     True
# │    │    │    └─conv.weight                                                                 ├─7,680
# │    │    │    └─bn.weight                                                                   ├─16
# │    │    │    └─bn.bias                                                                     └─16
# │    │    └─BasicConv2d: 3-22            [10, 16, 2, 2]            [10, 48, 2, 2]            7,008                     True
# │    │    │    └─conv.weight                                                                 ├─6,912
# │    │    │    └─bn.weight                                                                   ├─48
# │    │    │    └─bn.bias                                                                     └─48
# │    └─Sequential: 2-18                  [10, 480, 2, 2]           [10, 64, 2, 2]            --                        True
# │    │    └─1.conv.weight                                                                    ├─30,720
# │    │    └─1.bn.weight                                                                      ├─64
# │    │    └─1.bn.bias                                                                        └─64
# │    │    └─MaxPool2d: 3-23              [10, 480, 2, 2]           [10, 480, 2, 2]           --                        --
# │    │    └─BasicConv2d: 3-24            [10, 480, 2, 2]           [10, 64, 2, 2]            30,848                    True
# │    │    │    └─conv.weight                                                                 ├─30,720
# │    │    │    └─bn.weight                                                                   ├─64
# │    │    │    └─bn.bias                                                                     └─64
# ├─Inception: 1-10                        [10, 512, 2, 2]           [10, 512, 2, 2]           --                        True
# │    └─branch1.conv.weight                                                                   ├─81,920
# │    └─branch1.bn.weight                                                                     ├─160
# │    └─branch1.bn.bias                                                                       ├─160
# │    └─branch2.0.conv.weight                                                                 ├─57,344
# │    └─branch2.0.bn.weight                                                                   ├─112
# │    └─branch2.0.bn.bias                                                                     ├─112
# │    └─branch2.1.conv.weight                                                                 ├─225,792
# │    └─branch2.1.bn.weight                                                                   ├─224
# │    └─branch2.1.bn.bias                                                                     ├─224
# │    └─branch3.0.conv.weight                                                                 ├─12,288
# │    └─branch3.0.bn.weight                                                                   ├─24
# │    └─branch3.0.bn.bias                                                                     ├─24
# │    └─branch3.1.conv.weight                                                                 ├─13,824
# │    └─branch3.1.bn.weight                                                                   ├─64
# │    └─branch3.1.bn.bias                                                                     ├─64
# │    └─branch4.1.conv.weight                                                                 ├─32,768
# │    └─branch4.1.bn.weight                                                                   ├─64
# │    └─branch4.1.bn.bias                                                                     └─64
# │    └─BasicConv2d: 2-19                 [10, 512, 2, 2]           [10, 160, 2, 2]           --                        True
# │    │    └─conv.weight                                                                      ├─81,920
# │    │    └─bn.weight                                                                        ├─160
# │    │    └─bn.bias                                                                          └─160
# │    │    └─Conv2d: 3-25                 [10, 512, 2, 2]           [10, 160, 2, 2]           81,920                    True
# │    │    │    └─weight                                                                      └─81,920
# │    │    └─BatchNorm2d: 3-26            [10, 160, 2, 2]           [10, 160, 2, 2]           320                       True
# │    │    │    └─weight                                                                      ├─160
# │    │    │    └─bias                                                                        └─160
# │    └─Sequential: 2-20                  [10, 512, 2, 2]           [10, 224, 2, 2]           --                        True
# │    │    └─0.conv.weight                                                                    ├─57,344
# │    │    └─0.bn.weight                                                                      ├─112
# │    │    └─0.bn.bias                                                                        ├─112
# │    │    └─1.conv.weight                                                                    ├─225,792
# │    │    └─1.bn.weight                                                                      ├─224
# │    │    └─1.bn.bias                                                                        └─224
# │    │    └─BasicConv2d: 3-27            [10, 512, 2, 2]           [10, 112, 2, 2]           57,568                    True
# │    │    │    └─conv.weight                                                                 ├─57,344
# │    │    │    └─bn.weight                                                                   ├─112
# │    │    │    └─bn.bias                                                                     └─112
# │    │    └─BasicConv2d: 3-28            [10, 112, 2, 2]           [10, 224, 2, 2]           226,240                   True
# │    │    │    └─conv.weight                                                                 ├─225,792
# │    │    │    └─bn.weight                                                                   ├─224
# │    │    │    └─bn.bias                                                                     └─224
# │    └─Sequential: 2-21                  [10, 512, 2, 2]           [10, 64, 2, 2]            --                        True
# │    │    └─0.conv.weight                                                                    ├─12,288
# │    │    └─0.bn.weight                                                                      ├─24
# │    │    └─0.bn.bias                                                                        ├─24
# │    │    └─1.conv.weight                                                                    ├─13,824
# │    │    └─1.bn.weight                                                                      ├─64
# │    │    └─1.bn.bias                                                                        └─64
# │    │    └─BasicConv2d: 3-29            [10, 512, 2, 2]           [10, 24, 2, 2]            12,336                    True
# │    │    │    └─conv.weight                                                                 ├─12,288
# │    │    │    └─bn.weight                                                                   ├─24
# │    │    │    └─bn.bias                                                                     └─24
# │    │    └─BasicConv2d: 3-30            [10, 24, 2, 2]            [10, 64, 2, 2]            13,952                    True
# │    │    │    └─conv.weight                                                                 ├─13,824
# │    │    │    └─bn.weight                                                                   ├─64
# │    │    │    └─bn.bias                                                                     └─64
# │    └─Sequential: 2-22                  [10, 512, 2, 2]           [10, 64, 2, 2]            --                        True
# │    │    └─1.conv.weight                                                                    ├─32,768
# │    │    └─1.bn.weight                                                                      ├─64
# │    │    └─1.bn.bias                                                                        └─64
# │    │    └─MaxPool2d: 3-31              [10, 512, 2, 2]           [10, 512, 2, 2]           --                        --
# │    │    └─BasicConv2d: 3-32            [10, 512, 2, 2]           [10, 64, 2, 2]            32,896                    True
# │    │    │    └─conv.weight                                                                 ├─32,768
# │    │    │    └─bn.weight                                                                   ├─64
# │    │    │    └─bn.bias                                                                     └─64
# ├─Inception: 1-11                        [10, 512, 2, 2]           [10, 512, 2, 2]           --                        True
# │    └─branch1.conv.weight                                                                   ├─65,536
# │    └─branch1.bn.weight                                                                     ├─128
# │    └─branch1.bn.bias                                                                       ├─128
# │    └─branch2.0.conv.weight                                                                 ├─65,536
# │    └─branch2.0.bn.weight                                                                   ├─128
# │    └─branch2.0.bn.bias                                                                     ├─128
# │    └─branch2.1.conv.weight                                                                 ├─294,912
# │    └─branch2.1.bn.weight                                                                   ├─256
# │    └─branch2.1.bn.bias                                                                     ├─256
# │    └─branch3.0.conv.weight                                                                 ├─12,288
# │    └─branch3.0.bn.weight                                                                   ├─24
# │    └─branch3.0.bn.bias                                                                     ├─24
# │    └─branch3.1.conv.weight                                                                 ├─13,824
# │    └─branch3.1.bn.weight                                                                   ├─64
# │    └─branch3.1.bn.bias                                                                     ├─64
# │    └─branch4.1.conv.weight                                                                 ├─32,768
# │    └─branch4.1.bn.weight                                                                   ├─64
# │    └─branch4.1.bn.bias                                                                     └─64
# │    └─BasicConv2d: 2-23                 [10, 512, 2, 2]           [10, 128, 2, 2]           --                        True
# │    │    └─conv.weight                                                                      ├─65,536
# │    │    └─bn.weight                                                                        ├─128
# │    │    └─bn.bias                                                                          └─128
# │    │    └─Conv2d: 3-33                 [10, 512, 2, 2]           [10, 128, 2, 2]           65,536                    True
# │    │    │    └─weight                                                                      └─65,536
# │    │    └─BatchNorm2d: 3-34            [10, 128, 2, 2]           [10, 128, 2, 2]           256                       True
# │    │    │    └─weight                                                                      ├─128
# │    │    │    └─bias                                                                        └─128
# │    └─Sequential: 2-24                  [10, 512, 2, 2]           [10, 256, 2, 2]           --                        True
# │    │    └─0.conv.weight                                                                    ├─65,536
# │    │    └─0.bn.weight                                                                      ├─128
# │    │    └─0.bn.bias                                                                        ├─128
# │    │    └─1.conv.weight                                                                    ├─294,912
# │    │    └─1.bn.weight                                                                      ├─256
# │    │    └─1.bn.bias                                                                        └─256
# │    │    └─BasicConv2d: 3-35            [10, 512, 2, 2]           [10, 128, 2, 2]           65,792                    True
# │    │    │    └─conv.weight                                                                 ├─65,536
# │    │    │    └─bn.weight                                                                   ├─128
# │    │    │    └─bn.bias                                                                     └─128
# │    │    └─BasicConv2d: 3-36            [10, 128, 2, 2]           [10, 256, 2, 2]           295,424                   True
# │    │    │    └─conv.weight                                                                 ├─294,912
# │    │    │    └─bn.weight                                                                   ├─256
# │    │    │    └─bn.bias                                                                     └─256
# │    └─Sequential: 2-25                  [10, 512, 2, 2]           [10, 64, 2, 2]            --                        True
# │    │    └─0.conv.weight                                                                    ├─12,288
# │    │    └─0.bn.weight                                                                      ├─24
# │    │    └─0.bn.bias                                                                        ├─24
# │    │    └─1.conv.weight                                                                    ├─13,824
# │    │    └─1.bn.weight                                                                      ├─64
# │    │    └─1.bn.bias                                                                        └─64
# │    │    └─BasicConv2d: 3-37            [10, 512, 2, 2]           [10, 24, 2, 2]            12,336                    True
# │    │    │    └─conv.weight                                                                 ├─12,288
# │    │    │    └─bn.weight                                                                   ├─24
# │    │    │    └─bn.bias                                                                     └─24
# │    │    └─BasicConv2d: 3-38            [10, 24, 2, 2]            [10, 64, 2, 2]            13,952                    True
# │    │    │    └─conv.weight                                                                 ├─13,824
# │    │    │    └─bn.weight                                                                   ├─64
# │    │    │    └─bn.bias                                                                     └─64
# │    └─Sequential: 2-26                  [10, 512, 2, 2]           [10, 64, 2, 2]            --                        True
# │    │    └─1.conv.weight                                                                    ├─32,768
# │    │    └─1.bn.weight                                                                      ├─64
# │    │    └─1.bn.bias                                                                        └─64
# │    │    └─MaxPool2d: 3-39              [10, 512, 2, 2]           [10, 512, 2, 2]           --                        --
# │    │    └─BasicConv2d: 3-40            [10, 512, 2, 2]           [10, 64, 2, 2]            32,896                    True
# │    │    │    └─conv.weight                                                                 ├─32,768
# │    │    │    └─bn.weight                                                                   ├─64
# │    │    │    └─bn.bias                                                                     └─64
# ├─Inception: 1-12                        [10, 512, 2, 2]           [10, 528, 2, 2]           --                        True
# │    └─branch1.conv.weight                                                                   ├─57,344
# │    └─branch1.bn.weight                                                                     ├─112
# │    └─branch1.bn.bias                                                                       ├─112
# │    └─branch2.0.conv.weight                                                                 ├─73,728
# │    └─branch2.0.bn.weight                                                                   ├─144
# │    └─branch2.0.bn.bias                                                                     ├─144
# │    └─branch2.1.conv.weight                                                                 ├─373,248
# │    └─branch2.1.bn.weight                                                                   ├─288
# │    └─branch2.1.bn.bias                                                                     ├─288
# │    └─branch3.0.conv.weight                                                                 ├─16,384
# │    └─branch3.0.bn.weight                                                                   ├─32
# │    └─branch3.0.bn.bias                                                                     ├─32
# │    └─branch3.1.conv.weight                                                                 ├─18,432
# │    └─branch3.1.bn.weight                                                                   ├─64
# │    └─branch3.1.bn.bias                                                                     ├─64
# │    └─branch4.1.conv.weight                                                                 ├─32,768
# │    └─branch4.1.bn.weight                                                                   ├─64
# │    └─branch4.1.bn.bias                                                                     └─64
# │    └─BasicConv2d: 2-27                 [10, 512, 2, 2]           [10, 112, 2, 2]           --                        True
# │    │    └─conv.weight                                                                      ├─57,344
# │    │    └─bn.weight                                                                        ├─112
# │    │    └─bn.bias                                                                          └─112
# │    │    └─Conv2d: 3-41                 [10, 512, 2, 2]           [10, 112, 2, 2]           57,344                    True
# │    │    │    └─weight                                                                      └─57,344
# │    │    └─BatchNorm2d: 3-42            [10, 112, 2, 2]           [10, 112, 2, 2]           224                       True
# │    │    │    └─weight                                                                      ├─112
# │    │    │    └─bias                                                                        └─112
# │    └─Sequential: 2-28                  [10, 512, 2, 2]           [10, 288, 2, 2]           --                        True
# │    │    └─0.conv.weight                                                                    ├─73,728
# │    │    └─0.bn.weight                                                                      ├─144
# │    │    └─0.bn.bias                                                                        ├─144
# │    │    └─1.conv.weight                                                                    ├─373,248
# │    │    └─1.bn.weight                                                                      ├─288
# │    │    └─1.bn.bias                                                                        └─288
# │    │    └─BasicConv2d: 3-43            [10, 512, 2, 2]           [10, 144, 2, 2]           74,016                    True
# │    │    │    └─conv.weight                                                                 ├─73,728
# │    │    │    └─bn.weight                                                                   ├─144
# │    │    │    └─bn.bias                                                                     └─144
# │    │    └─BasicConv2d: 3-44            [10, 144, 2, 2]           [10, 288, 2, 2]           373,824                   True
# │    │    │    └─conv.weight                                                                 ├─373,248
# │    │    │    └─bn.weight                                                                   ├─288
# │    │    │    └─bn.bias                                                                     └─288
# │    └─Sequential: 2-29                  [10, 512, 2, 2]           [10, 64, 2, 2]            --                        True
# │    │    └─0.conv.weight                                                                    ├─16,384
# │    │    └─0.bn.weight                                                                      ├─32
# │    │    └─0.bn.bias                                                                        ├─32
# │    │    └─1.conv.weight                                                                    ├─18,432
# │    │    └─1.bn.weight                                                                      ├─64
# │    │    └─1.bn.bias                                                                        └─64
# │    │    └─BasicConv2d: 3-45            [10, 512, 2, 2]           [10, 32, 2, 2]            16,448                    True
# │    │    │    └─conv.weight                                                                 ├─16,384
# │    │    │    └─bn.weight                                                                   ├─32
# │    │    │    └─bn.bias                                                                     └─32
# │    │    └─BasicConv2d: 3-46            [10, 32, 2, 2]            [10, 64, 2, 2]            18,560                    True
# │    │    │    └─conv.weight                                                                 ├─18,432
# │    │    │    └─bn.weight                                                                   ├─64
# │    │    │    └─bn.bias                                                                     └─64
# │    └─Sequential: 2-30                  [10, 512, 2, 2]           [10, 64, 2, 2]            --                        True
# │    │    └─1.conv.weight                                                                    ├─32,768
# │    │    └─1.bn.weight                                                                      ├─64
# │    │    └─1.bn.bias                                                                        └─64
# │    │    └─MaxPool2d: 3-47              [10, 512, 2, 2]           [10, 512, 2, 2]           --                        --
# │    │    └─BasicConv2d: 3-48            [10, 512, 2, 2]           [10, 64, 2, 2]            32,896                    True
# │    │    │    └─conv.weight                                                                 ├─32,768
# │    │    │    └─bn.weight                                                                   ├─64
# │    │    │    └─bn.bias                                                                     └─64
# ├─Inception: 1-13                        [10, 528, 2, 2]           [10, 832, 2, 2]           --                        True
# │    └─branch1.conv.weight                                                                   ├─135,168
# │    └─branch1.bn.weight                                                                     ├─256
# │    └─branch1.bn.bias                                                                       ├─256
# │    └─branch2.0.conv.weight                                                                 ├─84,480
# │    └─branch2.0.bn.weight                                                                   ├─160
# │    └─branch2.0.bn.bias                                                                     ├─160
# │    └─branch2.1.conv.weight                                                                 ├─460,800
# │    └─branch2.1.bn.weight                                                                   ├─320
# │    └─branch2.1.bn.bias                                                                     ├─320
# │    └─branch3.0.conv.weight                                                                 ├─16,896
# │    └─branch3.0.bn.weight                                                                   ├─32
# │    └─branch3.0.bn.bias                                                                     ├─32
# │    └─branch3.1.conv.weight                                                                 ├─36,864
# │    └─branch3.1.bn.weight                                                                   ├─128
# │    └─branch3.1.bn.bias                                                                     ├─128
# │    └─branch4.1.conv.weight                                                                 ├─67,584
# │    └─branch4.1.bn.weight                                                                   ├─128
# │    └─branch4.1.bn.bias                                                                     └─128
# │    └─BasicConv2d: 2-31                 [10, 528, 2, 2]           [10, 256, 2, 2]           --                        True
# │    │    └─conv.weight                                                                      ├─135,168
# │    │    └─bn.weight                                                                        ├─256
# ...
# │    │    └─MaxPool2d: 3-55              [10, 528, 2, 2]           [10, 528, 2, 2]           --                        --
# │    │    └─BasicConv2d: 3-56            [10, 528, 2, 2]           [10, 128, 2, 2]           67,840                    True
# │    │    │    └─conv.weight                                                                 ├─67,584
# │    │    │    └─bn.weight                                                                   ├─128
# │    │    │    └─bn.bias                                                                     └─128
# ├─MaxPool2d: 1-14                        [10, 832, 2, 2]           [10, 832, 1, 1]           --                        --
# ├─Inception: 1-15                        [10, 832, 1, 1]           [10, 832, 1, 1]           --                        True
# │    └─branch1.conv.weight                                                                   ├─212,992
# │    └─branch1.bn.weight                                                                     ├─256
# │    └─branch1.bn.bias                                                                       ├─256
# │    └─branch2.0.conv.weight                                                                 ├─133,120
# │    └─branch2.0.bn.weight                                                                   ├─160
# │    └─branch2.0.bn.bias                                                                     ├─160
# │    └─branch2.1.conv.weight                                                                 ├─460,800
# │    └─branch2.1.bn.weight                                                                   ├─320
# │    └─branch2.1.bn.bias                                                                     ├─320
# │    └─branch3.0.conv.weight                                                                 ├─26,624
# │    └─branch3.0.bn.weight                                                                   ├─32
# │    └─branch3.0.bn.bias                                                                     ├─32
# │    └─branch3.1.conv.weight                                                                 ├─36,864
# │    └─branch3.1.bn.weight                                                                   ├─128
# │    └─branch3.1.bn.bias                                                                     ├─128
# │    └─branch4.1.conv.weight                                                                 ├─106,496
# │    └─branch4.1.bn.weight                                                                   ├─128
# │    └─branch4.1.bn.bias                                                                     └─128
# │    └─BasicConv2d: 2-35                 [10, 832, 1, 1]           [10, 256, 1, 1]           --                        True
# │    │    └─conv.weight                                                                      ├─212,992
# │    │    └─bn.weight                                                                        ├─256
# │    │    └─bn.bias                                                                          └─256
# │    │    └─Conv2d: 3-57                 [10, 832, 1, 1]           [10, 256, 1, 1]           212,992                   True
# │    │    │    └─weight                                                                      └─212,992
# │    │    └─BatchNorm2d: 3-58            [10, 256, 1, 1]           [10, 256, 1, 1]           512                       True
# │    │    │    └─weight                                                                      ├─256
# │    │    │    └─bias                                                                        └─256
# │    └─Sequential: 2-36                  [10, 832, 1, 1]           [10, 320, 1, 1]           --                        True
# │    │    └─0.conv.weight                                                                    ├─133,120
# │    │    └─0.bn.weight                                                                      ├─160
# │    │    └─0.bn.bias                                                                        ├─160
# │    │    └─1.conv.weight                                                                    ├─460,800
# │    │    └─1.bn.weight                                                                      ├─320
# │    │    └─1.bn.bias                                                                        └─320
# │    │    └─BasicConv2d: 3-59            [10, 832, 1, 1]           [10, 160, 1, 1]           133,440                   True
# │    │    │    └─conv.weight                                                                 ├─133,120
# │    │    │    └─bn.weight                                                                   ├─160
# │    │    │    └─bn.bias                                                                     └─160
# │    │    └─BasicConv2d: 3-60            [10, 160, 1, 1]           [10, 320, 1, 1]           461,440                   True
# │    │    │    └─conv.weight                                                                 ├─460,800
# │    │    │    └─bn.weight                                                                   ├─320
# │    │    │    └─bn.bias                                                                     └─320
# │    └─Sequential: 2-37                  [10, 832, 1, 1]           [10, 128, 1, 1]           --                        True
# │    │    └─0.conv.weight                                                                    ├─26,624
# │    │    └─0.bn.weight                                                                      ├─32
# │    │    └─0.bn.bias                                                                        ├─32
# │    │    └─1.conv.weight                                                                    ├─36,864
# │    │    └─1.bn.weight                                                                      ├─128
# │    │    └─1.bn.bias                                                                        └─128
# │    │    └─BasicConv2d: 3-61            [10, 832, 1, 1]           [10, 32, 1, 1]            26,688                    True
# │    │    │    └─conv.weight                                                                 ├─26,624
# │    │    │    └─bn.weight                                                                   ├─32
# │    │    │    └─bn.bias                                                                     └─32
# │    │    └─BasicConv2d: 3-62            [10, 32, 1, 1]            [10, 128, 1, 1]           37,120                    True
# │    │    │    └─conv.weight                                                                 ├─36,864
# │    │    │    └─bn.weight                                                                   ├─128
# │    │    │    └─bn.bias                                                                     └─128
# │    └─Sequential: 2-38                  [10, 832, 1, 1]           [10, 128, 1, 1]           --                        True
# │    │    └─1.conv.weight                                                                    ├─106,496
# │    │    └─1.bn.weight                                                                      ├─128
# │    │    └─1.bn.bias                                                                        └─128
# │    │    └─MaxPool2d: 3-63              [10, 832, 1, 1]           [10, 832, 1, 1]           --                        --
# │    │    └─BasicConv2d: 3-64            [10, 832, 1, 1]           [10, 128, 1, 1]           106,752                   True
# │    │    │    └─conv.weight                                                                 ├─106,496
# │    │    │    └─bn.weight                                                                   ├─128
# │    │    │    └─bn.bias                                                                     └─128
# ├─Inception: 1-16                        [10, 832, 1, 1]           [10, 1024, 1, 1]          --                        True
# │    └─branch1.conv.weight                                                                   ├─319,488
# │    └─branch1.bn.weight                                                                     ├─384
# │    └─branch1.bn.bias                                                                       ├─384
# │    └─branch2.0.conv.weight                                                                 ├─159,744
# │    └─branch2.0.bn.weight                                                                   ├─192
# │    └─branch2.0.bn.bias                                                                     ├─192
# │    └─branch2.1.conv.weight                                                                 ├─663,552
# │    └─branch2.1.bn.weight                                                                   ├─384
# │    └─branch2.1.bn.bias                                                                     ├─384
# │    └─branch3.0.conv.weight                                                                 ├─39,936
# │    └─branch3.0.bn.weight                                                                   ├─48
# │    └─branch3.0.bn.bias                                                                     ├─48
# │    └─branch3.1.conv.weight                                                                 ├─55,296
# │    └─branch3.1.bn.weight                                                                   ├─128
# │    └─branch3.1.bn.bias                                                                     ├─128
# │    └─branch4.1.conv.weight                                                                 ├─106,496
# │    └─branch4.1.bn.weight                                                                   ├─128
# │    └─branch4.1.bn.bias                                                                     └─128
# │    └─BasicConv2d: 2-39                 [10, 832, 1, 1]           [10, 384, 1, 1]           --                        True
# │    │    └─conv.weight                                                                      ├─319,488
# │    │    └─bn.weight                                                                        ├─384
# │    │    └─bn.bias                                                                          └─384
# │    │    └─Conv2d: 3-65                 [10, 832, 1, 1]           [10, 384, 1, 1]           319,488                   True
# │    │    │    └─weight                                                                      └─319,488
# │    │    └─BatchNorm2d: 3-66            [10, 384, 1, 1]           [10, 384, 1, 1]           768                       True
# │    │    │    └─weight                                                                      ├─384
# │    │    │    └─bias                                                                        └─384
# │    └─Sequential: 2-40                  [10, 832, 1, 1]           [10, 384, 1, 1]           --                        True
# │    │    └─0.conv.weight                                                                    ├─159,744
# │    │    └─0.bn.weight                                                                      ├─192
# │    │    └─0.bn.bias                                                                        ├─192
# │    │    └─1.conv.weight                                                                    ├─663,552
# │    │    └─1.bn.weight                                                                      ├─384
# │    │    └─1.bn.bias                                                                        └─384
# │    │    └─BasicConv2d: 3-67            [10, 832, 1, 1]           [10, 192, 1, 1]           160,128                   True
# │    │    │    └─conv.weight                                                                 ├─159,744
# │    │    │    └─bn.weight                                                                   ├─192
# │    │    │    └─bn.bias                                                                     └─192
# │    │    └─BasicConv2d: 3-68            [10, 192, 1, 1]           [10, 384, 1, 1]           664,320                   True
# │    │    │    └─conv.weight                                                                 ├─663,552
# │    │    │    └─bn.weight                                                                   ├─384
# │    │    │    └─bn.bias                                                                     └─384
# │    └─Sequential: 2-41                  [10, 832, 1, 1]           [10, 128, 1, 1]           --                        True
# │    │    └─0.conv.weight                                                                    ├─39,936
# │    │    └─0.bn.weight                                                                      ├─48
# │    │    └─0.bn.bias                                                                        ├─48
# │    │    └─1.conv.weight                                                                    ├─55,296
# │    │    └─1.bn.weight                                                                      ├─128
# │    │    └─1.bn.bias                                                                        └─128
# │    │    └─BasicConv2d: 3-69            [10, 832, 1, 1]           [10, 48, 1, 1]            40,032                    True
# │    │    │    └─conv.weight                                                                 ├─39,936
# │    │    │    └─bn.weight                                                                   ├─48
# │    │    │    └─bn.bias                                                                     └─48
# │    │    └─BasicConv2d: 3-70            [10, 48, 1, 1]            [10, 128, 1, 1]           55,552                    True
# │    │    │    └─conv.weight                                                                 ├─55,296
# │    │    │    └─bn.weight                                                                   ├─128
# │    │    │    └─bn.bias                                                                     └─128
# │    └─Sequential: 2-42                  [10, 832, 1, 1]           [10, 128, 1, 1]           --                        True
# │    │    └─1.conv.weight                                                                    ├─106,496
# │    │    └─1.bn.weight                                                                      ├─128
# │    │    └─1.bn.bias                                                                        └─128
# │    │    └─MaxPool2d: 3-71              [10, 832, 1, 1]           [10, 832, 1, 1]           --                        --
# │    │    └─BasicConv2d: 3-72            [10, 832, 1, 1]           [10, 128, 1, 1]           106,752                   True
# │    │    │    └─conv.weight                                                                 ├─106,496
# │    │    │    └─bn.weight                                                                   ├─128
# │    │    │    └─bn.bias                                                                     └─128
# ├─AdaptiveAvgPool2d: 1-17                [10, 1024, 1, 1]          [10, 1024, 1, 1]          --                        --
# ├─Dropout: 1-18                          [10, 1024]                [10, 1024]                --                        --
# ├─Linear: 1-19                           [10, 1024]                [10, 10]                  10,250                    True
# │    └─weight                                                                                ├─10,240
# │    └─bias                                                                                  └─10
# ============================================================================================================================================
# Total params: 5,610,154
# Trainable params: 5,610,154
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 305.83
# ============================================================================================================================================
# Input size (MB): 0.12
# Forward/backward pass size (MB): 10.54
# Params size (MB): 22.44
# Estimated Total Size (MB): 33.10
# ============================================================================================================================================

# %%
def train_step(model, loss_fn, optimizer, images, labels):
    model.train()
    outputs = model(images)
    logits = outputs.logits if isinstance(outputs, torchvision.models.GoogLeNetOutputs) else outputs
    loss = loss_fn(logits, labels)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    return loss

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), weight_decay=0.0001)

# %%
for epoch in range(30):
    for batch in train_loader:
        images, labels = batch
        images, labels = images.to(device), labels.to(device)
        loss = train_step(model, loss_fn, optimizer, images, labels)
    print(f'Epoch [{epoch + 1}/30], Loss: {loss.item()}')
# Out:
# Epoch [1/30], Loss: 0.5446175336837769
# Epoch [2/30], Loss: 1.1031750440597534
# Epoch [3/30], Loss: 0.9356451034545898
# Epoch [4/30], Loss: 0.13304513692855835
# Epoch [5/30], Loss: 0.4555344581604004
# Epoch [6/30], Loss: 0.2815956175327301
# Epoch [7/30], Loss: 0.6705600023269653
# Epoch [8/30], Loss: 0.6217655539512634
# Epoch [9/30], Loss: 0.09291879087686539
# Epoch [10/30], Loss: 0.5446655750274658
# Epoch [11/30], Loss: 0.3005693852901459
# Epoch [12/30], Loss: 0.0783669725060463
# Epoch [13/30], Loss: 0.15164893865585327
# Epoch [14/30], Loss: 0.36844319105148315
# Epoch [15/30], Loss: 0.5716931223869324
# Epoch [16/30], Loss: 0.01792934350669384
# Epoch [17/30], Loss: 0.07769284397363663
# Epoch [18/30], Loss: 0.004536966327577829
# Epoch [19/30], Loss: 0.02278190478682518
# Epoch [20/30], Loss: 0.10449191182851791
# Epoch [21/30], Loss: 0.5532865524291992
# Epoch [22/30], Loss: 0.007377977017313242
# Epoch [23/30], Loss: 0.21821458637714386
# Epoch [24/30], Loss: 0.14778362214565277
# Epoch [25/30], Loss: 0.09380344301462173
# Epoch [26/30], Loss: 0.0029507698491215706
# Epoch [27/30], Loss: 0.035290319472551346
# Epoch [28/30], Loss: 0.0017558158142492175
# Epoch [29/30], Loss: 0.013088652864098549
# Epoch [30/30], Loss: 0.039595503360033035

# %%
accuracy = 0
model.eval()
with torch.inference_mode():
    for batch in test_loader:
        images, labels = batch
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        logits = outputs.logits if isinstance(outputs, torchvision.models.GoogLeNetOutputs) else outputs
        _, predicted = torch.max(logits, 1)
        accuracy += (predicted == labels).sum().item()

print(f'Accuracy: {accuracy / len(test_dataset)}')
# Out:
# Accuracy: 0.8188
